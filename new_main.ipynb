# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from modules.data_store import save_df_csv, load_df_csv, save_transcript, load_transcript, transcript_exists
from modules.retrieval import build_faiss, load_faiss, load_corpus_from_df, filtered_search
from modules.pipelines import *
from modules.embeddings import embedding_setup
from modules.processing import spacy_setup
from modules.transcript_extraction import nltk_setup
from modules.comment_extraction import api_setup
from modules.multiagent import build_graph

import modules.multiagent as agent
import pandas as pd
import mlflow

# %%
nltk_setup()
video = 'Y8yTY_7w3KA'
nlp = spacy_setup()
embedding = embedding_setup()
youtube_api = api_setup()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Abdallah\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Abdallah\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Abdallah\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Abdallah\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# nltk packages downloaded
# loaded youtube api

# %%
comments_1_df = extract_video_comments_full(video,youtube_api,nlp, embedding)
comments_1_df.head()
# Out:
# Video Y8yTY_7w3KA: collected 129 rows so far
# Video Y8yTY_7w3KA: collected 256 rows so far
# extracted 256 comments
# save Y8yTY_7w3KA_raw.csv of 256 cols  to model_data\Y8yTY_7w3KA_raw.csv
# Final number of comments after cleaning: 240
# Comments removed: 16
# TF-IDF matrix shape: (240, 280)
# processed 240 comments
#                                            source_id source_type     video_id  \
# 0                         UgzjI6TjvTQiaNdFJDh4AaABAg     comment  Y8yTY_7w3KA
# 1  UgzjI6TjvTQiaNdFJDh4AaABAg.9voUleYQpWB9vp-UsnhkGH     comment  Y8yTY_7w3KA
# 2  UgzjI6TjvTQiaNdFJDh4AaABAg.9voUleYQpWB9vpI9k1jApB     comment  Y8yTY_7w3KA
# 3  UgzjI6TjvTQiaNdFJDh4AaABAg.9voUleYQpWB9vytQZ977iX     comment  Y8yTY_7w3KA
# 4  UgzjI6TjvTQiaNdFJDh4AaABAg.9voUleYQpWB9wBY-12Xroy     comment  Y8yTY_7w3KA
#
#                     parent_id  is_reply        author  \
# 0                        None     False  @autogefuehl
# 1  UgzjI6TjvTQiaNdFJDh4AaABAg      True      @Rokii92
# 2  UgzjI6TjvTQiaNdFJDh4AaABAg      True       @Elaba_
# 3  UgzjI6TjvTQiaNdFJDh4AaABAg      True  @whatnow9653
# 4  UgzjI6TjvTQiaNdFJDh4AaABAg      True     @rondhole
#
#                                                 text  like_count  public  \
# 0  Note that contrary to the first info and contr...          57    True
# 1                        you mean "horror sound"? :D           0    True
# 2                     Tammy AI is without a job now.           0    True
# 3  1:29    lolly pops,  cherry pies,  cream puffs...           0    True
# 4  What separate a good and bad BEV is the heat m...           0    True
#
#                                           clean_text  \
# 0  Note that contrary to the first info and contr...
# 1                        you mean "horror sound"? :D
# 2                     Tammy AI is without a job now.
# 3  1:29 lolly pops, cherry pies, cream puffs, ice...
# 4  What separate a good and bad BEV is the heat m...
#
#                                             entities  sentiment_score  \
# 0  [BYD, Germany, 02:35 Sporty, RWD, AWD, 04:19 S...           0.8442
# 1                                                 []           0.0857
# 2                                         [Tammy AI]           0.0000
# 3                                                 []           0.5106
# 4                                 [Octovalve, Tesla]           0.4404
#
#   sentiment                                keywords  \
# 0  Positive  [byd, comfort, contrary, 29, steering]
# 1  Positive                           [mean, sound]
# 2   Neutral                                      []
# 3  Positive       [cream, 29, ice cream, ice, free]
# 4  Positive    [tesla, bad, market, compared, long]
#
#                                            embedding
# 0  [-0.049880978, -0.009711982, 0.06287992, 0.010...
# 1  [-0.120427154, 0.0056267357, 0.007439199, -0.0...
# 2  [-0.15995634, -0.014780474, 0.06653771, -0.014...
# 3  [-0.09148398, 0.010680194, 0.031913865, 0.0315...
# 4  [-0.081726454, -0.014096241, 0.012966923, 0.00...

# %%
video2 = 'V0wtNI-rzSg'
comments_2_df = extract_video_comments_full(video2,youtube_api,nlp, embedding)
comments_2_df.head()
# Out:
# Video V0wtNI-rzSg: collected 100 rows so far
# Video V0wtNI-rzSg: collected 202 rows so far
# extracted 202 comments
# save V0wtNI-rzSg_raw.csv of 202 cols  to model_data\V0wtNI-rzSg_raw.csv
# Final number of comments after cleaning: 177
# Comments removed: 25
# TF-IDF matrix shape: (177, 98)
# processed 177 comments
#                     source_id source_type     video_id parent_id  is_reply  \
# 0  UgyEF1U2INCc0EZxf_t4AaABAg     comment  V0wtNI-rzSg      None     False
# 1  Ugz5s0PKBupBXK4Ugld4AaABAg     comment  V0wtNI-rzSg      None     False
# 2  UgyqNGNLVqXddAdC5Wx4AaABAg     comment  V0wtNI-rzSg      None     False
# 3  Ugx9DGiRIsGm3DsEPgt4AaABAg     comment  V0wtNI-rzSg      None     False
# 4  UgyaUiiMq4imxJQceZB4AaABAg     comment  V0wtNI-rzSg      None     False
#
#              author                                               text  \
# 0  @geoffwalker7530  Note the crap door handles, sale killer straig...
# 1      @marceln3107        *In the MY2026, BYD dismissed this feature.
# 2     @carlkirk3467  Even better if there were no touchscreens to d...
# 3   @nobodyshero200  So interesting you chose an EV as a daily. Tha...
# 4   @williamwildcat       I don’t care how nice it is it’s a stupid ev
#
#    like_count  public                                         clean_text  \
# 0           0    True  Note the crap door handles, sale killer straig...
# 1           0    True        *In the MY2026, BYD dismissed this feature.
# 2           0    True  Even better if there were no touchscreens to d...
# 3           0    True  So interesting you chose an EV as a daily. Tha...
# 4           0    True       I don’t care how nice it is it’s a stupid ev
#
#         entities  sentiment_score sentiment  \
# 0             []          -0.7184  Negative
# 1  [MY2026, BYD]           0.0000   Neutral
# 2             []          -0.1280  Negative
# 3             []          -0.1298  Negative
# 4             []           0.3818  Positive
#
#                                  keywords  \
# 0                                  [crap]
# 1                          [feature, byd]
# 2                        [driver, better]
# 3  [interesting, daily, ev, really, cars]
# 4                 [nice, stupid, ev, don]
#
#                                            embedding
# 0  [-0.13544238, -0.038832527, 0.042742647, 0.017...
# 1  [-0.13474578, -0.022500524, 0.045074645, -0.00...
# 2  [-0.11380915, -0.039813634, 0.050478853, 0.047...
# 3  [-0.13519152, -0.0036311098, 0.06373591, 0.010...
# 4  [-0.16873242, -0.041292094, 0.059854172, 0.029...

# %%
transcript_1_df = extract_video_transcript_full(video,nlp,embedding,win=60)
transcript_2_df = extract_video_transcript_full(video2,nlp,embedding,win=60)
# Out:
# transcript exist,s loading transcript
# loaded 358 segments from model_data\Y8yTY_7w3KA.json
# processed transcript for Y8yTY_7w3KA of 22
# saved 27 segments -> model_data\V0wtNI-rzSg.json
# transcript does not exist, saving raw transcript
# loaded 27 segments from model_data\V0wtNI-rzSg.json
# processed transcript for V0wtNI-rzSg of 1

# %%
all_dfs = []
all_dfs.append(comments_1_df)
all_dfs.append(comments_2_df)
all_dfs.append(transcript_1_df)
all_dfs.append(transcript_2_df)
meta_df = pd.concat(all_dfs, ignore_index=True)
print(len(meta_df), "total rows")
print(meta_df["source_type"].value_counts())
print(meta_df["video_id"].value_counts())
# Out:
# 440 total rows
# source_type
# comment       417
# transcript     23
# Name: count, dtype: int64
# video_id
# Y8yTY_7w3KA    262
# V0wtNI-rzSg    178
# Name: count, dtype: int64

# %%
texts, vectors, metadata = load_corpus_from_df(meta_df)
vs = build_faiss(texts, vectors, metadata, embedding)
save_df_csv(meta_df,f'meta_data.csv',True)
# Out:
# loaded 440 from                                              source_id source_type  \
# 0                           UgzjI6TjvTQiaNdFJDh4AaABAg     comment
# 1    UgzjI6TjvTQiaNdFJDh4AaABAg.9voUleYQpWB9vp-UsnhkGH     comment
# 2    UgzjI6TjvTQiaNdFJDh4AaABAg.9voUleYQpWB9vpI9k1jApB     comment
# 3    UgzjI6TjvTQiaNdFJDh4AaABAg.9voUleYQpWB9vytQZ977iX     comment
# 4    UgzjI6TjvTQiaNdFJDh4AaABAg.9voUleYQpWB9wBY-12Xroy     comment
# ..                                                 ...         ...
# 435                                   Y8yTY_7w3KA_t_18  transcript
# 436                                   Y8yTY_7w3KA_t_19  transcript
# 437                                   Y8yTY_7w3KA_t_20  transcript
# 438                                   Y8yTY_7w3KA_t_21  transcript
# 439                                    V0wtNI-rzSg_t_0  transcript
#
#         video_id                   parent_id is_reply        author  \
# 0    Y8yTY_7w3KA                        None    False  @autogefuehl
# 1    Y8yTY_7w3KA  UgzjI6TjvTQiaNdFJDh4AaABAg     True      @Rokii92
# 2    Y8yTY_7w3KA  UgzjI6TjvTQiaNdFJDh4AaABAg     True       @Elaba_
# 3    Y8yTY_7w3KA  UgzjI6TjvTQiaNdFJDh4AaABAg     True  @whatnow9653
# 4    Y8yTY_7w3KA  UgzjI6TjvTQiaNdFJDh4AaABAg     True     @rondhole
# ..           ...                         ...      ...           ...
# 435  Y8yTY_7w3KA                         NaN      NaN           NaN
# 436  Y8yTY_7w3KA                         NaN      NaN           NaN
# 437  Y8yTY_7w3KA                         NaN      NaN           NaN
# 438  Y8yTY_7w3KA                         NaN      NaN           NaN
# 439  V0wtNI-rzSg                         NaN      NaN           NaN
#
#                                                   text  like_count public  \
# 0    Note that contrary to the first info and contr...        57.0   True
# 1                          you mean "horror sound"? :D         0.0   True
# 2                       Tammy AI is without a job now.         0.0   True
# 3    1:29    lolly pops,  cherry pies,  cream puffs...         0.0   True
# 4    What separate a good and bad BEV is the heat m...         0.0   True
# ..                                                 ...         ...    ...
# 435  So, hmm. Did I find out something here? Well, ...         NaN    NaN
# 436  So, what else did I realize while driving? The...         NaN    NaN
# 437  Does it drive better than the Tesla Model 3? Y...         NaN    NaN
# 438  kilometers, including some accelerations, so t...         NaN    NaN
# 439  I've just got the key to this the byd seal so ...         NaN    NaN
#
#                                             clean_text  \
# 0    Note that contrary to the first info and contr...
# 1                          you mean "horror sound"? :D
# 2                       Tammy AI is without a job now.
# 3    1:29 lolly pops, cherry pies, cream puffs, ice...
# 4    What separate a good and bad BEV is the heat m...
# ..                                                 ...
# 435                                                NaN
# 436                                                NaN
# 437                                                NaN
# 438                                                NaN
# 439                                                NaN
#
#                                               entities  sentiment_score  \
# 0    [BYD, Germany, 02:35 Sporty, RWD, AWD, 04:19 S...           0.8442
# 1                                                   []           0.0857
# 2                                           [Tammy AI]           0.0000
# 3                                                   []           0.5106
# 4                                   [Octovalve, Tesla]           0.4404
# ..                                                 ...              ...
# 435                              [the German Autobahn]              NaN
# 436  [ACC, Zeeks, Xpeng, Tang, European, Interior, ...              NaN
# 437          [Model 3, the Model 3, NIO, BYD, Chinese]              NaN
# 438                              [the Model 3, German]              NaN
# 439                                   [Drive, Android]              NaN
#
#     sentiment                                keywords  \
# 0    Positive  [byd, comfort, contrary, 29, steering]
# 1    Positive                           [mean, sound]
# 2     Neutral                                      []
# 3    Positive       [cream, 29, ice cream, ice, free]
# 4    Positive    [tesla, bad, market, compared, long]
# ..        ...                                     ...
# 435       NaN                                     NaN
# 436       NaN                                     NaN
# 437       NaN                                     NaN
# 438       NaN                                     NaN
# 439       NaN                                     NaN
#
#                                              embedding  chunk_index  \
# 0    [-0.049880978, -0.009711982, 0.06287992, 0.010...          NaN
# 1    [-0.120427154, 0.0056267357, 0.007439199, -0.0...          NaN
# 2    [-0.15995634, -0.014780474, 0.06653771, -0.014...          NaN
# 3    [-0.09148398, 0.010680194, 0.031913865, 0.0315...          NaN
# 4    [-0.081726454, -0.014096241, 0.012966923, 0.00...          NaN
# ..                                                 ...          ...
# 435  [-0.052086886, -0.037342507, 0.01632184, -0.02...         18.0
# 436  [-0.044880956, -0.04947504, 0.06816442, 0.0423...         19.0
# 437  [-0.0031119236, -0.06823776, 0.03640721, -0.00...         20.0
# 438  [0.006098774, -0.021101529, 0.010648282, 0.014...         21.0
# 439  [-0.09271054, -0.04319275, 0.04216051, 0.02521...          0.0
#
#      start_time                                       noun_phrases
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# ..          ...                                                ...
# 435      1123.1  [hmm, Did, something, Well, the German Autobah...
# 436      1184.3  [The ACC, five-kilometer steps, course, the as...
# 437      1245.2  [the Tesla Model, quick charging, course, a ch...
# 438      1306.0  [kilometers, some accelerations, a little bit,...
# 439         0.2  [the key, the byd seal, the time, the silly st...
#
# [440 rows x 18 columns]
# built + saved FAISS index (440 vectors) -> faiss_store
# save meta_data.csv of 440 cols  to model_data\meta_data.csv

# %%
from modules.retrieval import semantic_search

for q in ["is tesla better than byd?", "what is the battery capacity and range?"]:
    print(f"\nQ: {q}")
    for r in semantic_search(vs, q, k=5):
        print(r["source_type"], "|", r["text"][:70])
# Out:
# Q: is tesla better than byd?
# comment | ngl I might prefer byd over tesla
# comment | What type of idiot would say it's better than the model 3
# comment | Better than Tesla
# comment | The seats compared with the Tesla Model 3 are on another level. Test d
# comment | Clearly a premium product cannot be compared with the tesla model 3 in
#
# Q: what is the battery capacity and range?
# comment | How large is the frunk???!!!
# comment | And the battery works better in the freezing cold.
# comment | But does it charge at 1MW ? If not throw it in the bin.
# comment | Can't wait for EV cars to use solid state batteries.
# comment | 350 kilometers maybe. that is the cheapest ev u can have in china.

# %%
print("--- transcripts only ---")
for r in filtered_search(vs, "what is the battery capacity and range?",
                         source_type="transcript", k=5):
    print(r["source_type"], "|", r["text"][:70])

print("\n--- comments only ---")
for r in filtered_search(vs, "is tesla better than byd?",
                         source_type="comment", k=5):
    print(r["source_type"], "|", r["text"][:70])
# Out:
# --- transcripts only ---
# transcript | kilometers, including some accelerations, so that could even be a litt
# transcript | battery, 82.5 kilowatt hours net, and it's an LFP battery that is also
# transcript | I've just got the key to this the byd seal so for the time being all o
# transcript | have them, that's a pro in comparison to the Tesla Model 3. Then 15.6-
# transcript | Inside of the rear doors, also the nice microfiber insert, high-grade
#
# --- comments only ---
# comment | ngl I might prefer byd over tesla
# comment | Only a crazy person would pick a BYD instead of a Tesla. All other EV
# comment | What type of idiot would say it's better than the model 3
# comment | Better than Tesla
# comment | I test drove both this and the model 3 performance. The Tesla is by fa

# %%
agent.VECTORSTORE = vs
graph = build_graph()

with mlflow.start_run(run_name='rag_router_test'):
  for q in ['what is the battery capacity?', 'is tesla better than byd']:
    result = graph.invoke({'query': q})
    print(f'\nQ: {q}')
    print(f'category: {result["category"]}')
    print(f'answer: {result["answer"]}')
# Out:
# Q: what is the battery capacity?
# category: factual
# answer: The battery capacity is 82.5 kilowatt-hours (kWh).
#
# Q: is tesla better than byd
# category: opinion
# answer: The context contains conflicting opinions, with some stating BYD is better than Tesla and others claiming Tesla is superior. There is no clear consensus or definitive answer in the provided information.
