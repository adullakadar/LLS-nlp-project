# %% [markdown]
# <a href="https://colab.research.google.com/github/adullakadar/LLS-nlp-project/blob/main/Tesla_YouTube_Comments_Advanced%20(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from google.colab import userdata
dev = userdata.get('YT_API_KEY')

# %% [markdown]
# ## Pull All Comments

# %%
import googleapiclient.discovery
import pandas as pd

# %%
#Video 1 - https://www.youtube.com/watch?v=iueGI4CzP-0
# 5084 comments

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev
video_id = "iueGI4CzP-0"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId=video_id,
    maxResults=100
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId= video_id, maxResults=100, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df1 = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3591 entries, 0 to 3590
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      3591 non-null   object
#  1   updated_at  3591 non-null   object
#  2   like_count  3591 non-null   int64
#  3   text        3591 non-null   object
#  4   public      3591 non-null   bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 115.9+ KB

# %%
df1.head(10)
# Out:
#               author            updated_at  like_count  \
# 0         @screes620  2026-04-21T03:28:59Z           0
# 1  @BjornSmith-xv3xz  2026-03-15T18:34:27Z           2
# 2       @cigxhang486  2026-03-07T03:21:01Z           0
# 3     @Kenneth_James  2026-01-30T03:29:15Z           0
# 4    @francischan57c  2025-12-14T05:18:41Z           1
# 5  @markgabbidon5859  2025-12-06T03:43:27Z           0
# 6   @ajinkyamate7918  2025-11-24T02:53:46Z           0
# 7    @MenaMohmed-x3m  2025-11-17T20:16:56Z           1
# 8           @flynomo  2025-11-16T04:09:44Z           0
# 9       @coldragon06  2025-10-27T02:58:41Z           1
#
#                                                 text  public
# 0  2 Years later and this is the car i've got my ...    True
# 1  how it feels watching in the back of my dads t...    True
# 2  Wtf you have to do PRNDL on a screen? I will n...    True
# 3  Check his vibe change in the vid that came out...    True
# ...

# %%
#Video 2 - https://www.youtube.com/watch?v=52O3cYsyZMo
# 3157 comments (total = 8241)

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev
video_id = "52O3cYsyZMo"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId= video_id,
    maxResults=100
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId=video_id, maxResults=100, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df2 = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      1898 non-null   object
#  1   updated_at  1898 non-null   object
#  2   like_count  1898 non-null   int64
#  3   text        1898 non-null   object
#  4   public      1898 non-null   bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 61.3+ KB

# %%
df2.head(10)
# Out:
#                   author            updated_at  like_count  \
# 0          @triplejj9341  2026-05-05T15:36:41Z           0
# 1            @0x8badbeef  2026-02-28T04:55:29Z           0
# 2             @IGoFast76  2026-02-24T19:35:04Z           0
# 3    @triplicateatom8927  2026-01-31T03:50:35Z           0
# 4         @nagasreenu926  2026-01-06T10:18:36Z           0
# 5  @SirSquatchington-q2r  2026-01-02T19:35:26Z           0
# 6          @PhatVu-vl9xk  2025-12-13T05:52:21Z           0
# 7          @PhatVu-vl9xk  2025-12-13T05:52:09Z           0
# 8              @zr0dotiO  2025-11-09T11:05:04Z           0
# 9               @seeny13  2025-10-19T15:46:18Z           0
#
#                                                 text  public
# 0  TSLA NEEDS TO SELL STOCK, IMPROVE THE QUALITY ...    True
# 1  You say it handles better.  But can you feel t...    True
# 2  It still looks pretty much the same as every o...    True
# 3  Jesus loves y'all! ✝Put your faith and trust i...    True
# ...

# %%
# Video 3 - https://www.youtube.com/watch?v=XTeWKmlNmN8
# 329 comments (total = 8570)

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev
video_id = "XTeWKmlNmN8"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId= video_id,
    maxResults=100
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId=video_id, maxResults=100, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df3 = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      140 non-null    object
#  1   updated_at  140 non-null    object
#  2   like_count  140 non-null    int64
#  3   text        140 non-null    object
#  4   public      140 non-null    bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 4.6+ KB

# %%
df3.head(10)
# Out:
#                author            updated_at  like_count  \
# 0        @edmundscars  2025-10-09T19:32:21Z          19
# 1        @maxseltzer3  2026-05-14T14:09:57Z           0
# 2         @lomate1963  2026-05-13T18:36:17Z           0
# 3  @sandysanmaung4599  2026-05-13T18:11:30Z           0
# 4           @zane2673  2026-05-08T02:57:36Z           0
# 5           @schrimpf  2026-05-07T09:51:59Z           0
# 6        @user-NiqNiq  2026-04-30T18:48:21Z           0
# 7        @drsssssssss  2026-04-27T14:36:37Z           1
# 8            @mpak999  2026-04-20T15:25:04Z           0
# 9   @brandonscott6606  2026-04-15T17:53:27Z           0
#
#                                                 text  public
# 0  You know what we think, but what do you think ...    True
# 1  I like paying for features that I will use.  F...    True
# 2                               ❤ sheriff Labrador 😂    True
# 3  TESLA \nBuying Tesla excitement turned into di...    True
# ...

# %%
# Video 4 - https://www.youtube.com/watch?v=KAJFALcJjac
# 925 comments (total = 9495)

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev
video_id = "KAJFALcJjac"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId= video_id,
    maxResults=100
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId=video_id, maxResults=100, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df4 = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 686 entries, 0 to 685
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      686 non-null    object
#  1   updated_at  686 non-null    object
#  2   like_count  686 non-null    int64
#  3   text        686 non-null    object
#  4   public      686 non-null    bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 22.2+ KB

# %%
df4.head(10)
# Out:
#                                                 text
# 0  *UPDATED VIDEO FOR 2025*: https://youtu.be/XvN...
# 1  Do what everybody else is doing if you are oka...
# 2  @derrenmarcus2014 Exactly, money is always eag...
# 3  @thiagosilvano7859 I have been researching all...
# 4  I understand the fact that tomorrow isn't prom...
# 5  @andysyaputra1787 In situations like this,I al...
# 6  Lately I’ve been thinking of buying cryptocurr...
# 7  @marcoarigliani3460 My personal investment man...
# 8  @hossammoussa1127 Please do you mind sharing a...
# 9  @marcoarigliani3460 Daniel Christopher Downes ...
