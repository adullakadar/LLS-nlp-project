# %% [markdown]
# imports and setup

# %%
# to reload imports without having to reload window
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from modules.data_store import save_df_csv, load_df_csv, save_transcript, load_transcript, transcript_exists
from modules.retrieval import build_faiss, load_faiss, load_corpus_from_df, filtered_search
from modules.pipelines import *
from modules.embeddings import embedding_setup
from modules.processing import spacy_setup
from modules.transcript_extraction import nltk_setup
from modules.comment_extraction import api_setup
from modules.singleagent import build_graph
from modules.evaluation import evaluate_routing
import modules.singleagent as agent
import pandas as pd
import mlflow
from modules.topic_modeling import *

# %%
nltk_setup()
nlp = spacy_setup()
embedding = embedding_setup()
youtube_api = api_setup()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Abdallah\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Abdallah\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Abdallah\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Abdallah\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# nltk packages downloaded
# loaded youtube api

# %% [markdown]
# Comment extraction for all videos BYD

# %%
byd1='w_tCOgxXKwA'
byd2='DHRxnTPrzOQ'
byd3='KLiiOeMU9JQ'
byd4='Y8yTY_7w3KA'
byd5='eNYndWedZsE'
byd6='V0wtNI-rzSg'
byd7='JgySpSlQQyE'
byd8='gzHLv6rLSpQ'

# %%
# Runs comment extraction pipeline for each video. can be simplified but I want separate variables for testing purposes like doc length

# byd_1_df = extract_video_comments_full(byd1,youtube_api,nlp, embedding, limit = 2000)
# byd_2_df = extract_video_comments_full(byd2,youtube_api,nlp, embedding, limit = 2000)
# byd_3_df = extract_video_comments_full(byd3,youtube_api,nlp, embedding, limit = 2000)
# byd_4_df = extract_video_comments_full(byd4,youtube_api,nlp, embedding, limit = 2000)
# byd_5_df = extract_video_comments_full(byd5,youtube_api,nlp, embedding, limit = 2000)
# byd_6_df = extract_video_comments_full(byd6,youtube_api,nlp, embedding, limit = 2000)
# byd_7_df = extract_video_comments_full(byd7,youtube_api,nlp, embedding, limit = 2000)
# byd_8_df = extract_video_comments_full(byd8,youtube_api,nlp, embedding, limit = 2000)
byd_1_df.head()
# Out:
#                     source_id source_type     video_id parent_id  is_reply  \
# 0  UgzHKvcxfFMwwaFrABJ4AaABAg     comment  w_tCOgxXKwA       NaN     False
# 1  Ugyr7I1yA-AGQSiWnWZ4AaABAg     comment  w_tCOgxXKwA       NaN     False
# 2  UgzUIcn-8QFAs0l2jMd4AaABAg     comment  w_tCOgxXKwA       NaN     False
# 3  UgyBoTeyCgD9UtLqCMt4AaABAg     comment  w_tCOgxXKwA       NaN     False
# 4  Ugytx0WcuOpj0ISDZKZ4AaABAg     comment  w_tCOgxXKwA       NaN     False
#
#                author                                               text  \
# 0            @nzbrent           thanks for the mad review haha, all good
# 1         @drigon1630  I just don't fucking like the handle if electr...
# 2  @keeganmurrell5638  As a presenter, you are doing an incredible jo...
# 3      @peterreed3104  The Irony Using a Mobile phone while driving i...
# 4      @aymansyed1351  I had to comment. You're so funny. Can't wait ...
#
#    like_count  public                                         clean_text  \
# 0           0    True           thanks for the mad review haha, all good
# 1           0    True  I just don't fucking like the handle if electr...
# 2           0    True  As a presenter, you are doing an incredible jo...
# 3           0    True  The Irony Using a Mobile phone while driving i...
# 4           0    True  I had to comment. You're so funny. Can't wait ...
#
#                                             entities  sentiment_score  \
# 0                                                 []           0.6808
# 1                                                 []          -0.7373
# 2                                                 []           0.4926
# 3  [iPad, the Click of a Real Button, Software, L...          -0.9594
# 4                                                 []           0.5777
#
#   sentiment                                           keywords  \
# 0  Positive                       [haha, thanks, good, review]
# 1  Negative              [die, handle, stuff, going, electric]
# 2  Positive  [incredible, job, entertaining, doing, presenter]
# 3  Negative             [ev, mobile, upgrade, phone, turn car]
# 4  Positive                    [comment, wait, funny, reviews]
#
#                                            embedding
# 0  [-0.15534051, -0.04460014, 0.012359365, -0.026...
# 1  [-0.11953649, 0.003983694, 0.085625924, -0.025...
# 2  [-0.17006563, -0.040494792, 0.019697804, -0.03...
# 3  [-0.09100315, 0.03171054, 0.032680452, 0.02720...
# 4  [-0.096851036, 0.013732363, 0.051594086, -0.05...

# %%
# runs transcript pipeline for all videos, separat variables for same reason

byd_tr_1_df = extract_video_transcript_full(byd1,nlp,embedding,win=60)
byd_tr_2_df = extract_video_transcript_full(byd2,nlp,embedding,win=60)
byd_tr_3_df = extract_video_transcript_full(byd3,nlp,embedding,win=60)
byd_tr_4_df = extract_video_transcript_full(byd4,nlp,embedding,win=60)
byd_tr_5_df = extract_video_transcript_full(byd5,nlp,embedding,win=60)
byd_tr_6_df = extract_video_transcript_full(byd6,nlp,embedding,win=60)
# byd_tr_7_df = extract_video_transcript_full(byd7,nlp,embedding,win=60)
byd_tr_8_df = extract_video_transcript_full(byd8,nlp,embedding,win=60)
# Out:
# transcript exist,s loading transcript
# loaded 568 segments from model_data\w_tCOgxXKwA.json
# processed transcript for w_tCOgxXKwA of 23
# transcript exist,s loading transcript
# loaded 377 segments from model_data\DHRxnTPrzOQ.json
# processed transcript for DHRxnTPrzOQ of 15
# transcript exist,s loading transcript
# loaded 821 segments from model_data\KLiiOeMU9JQ.json
# processed transcript for KLiiOeMU9JQ of 31
# transcript exist,s loading transcript
# loaded 358 segments from model_data\Y8yTY_7w3KA.json
# processed transcript for Y8yTY_7w3KA of 22
# transcript exist,s loading transcript
# loaded 395 segments from model_data\eNYndWedZsE.json
# processed transcript for eNYndWedZsE of 17
# transcript exist,s loading transcript
# loaded 27 segments from model_data\V0wtNI-rzSg.json
# processed transcript for V0wtNI-rzSg of 1
# saved 294 segments -> model_data\gzHLv6rLSpQ.json
# transcript does not exist, saving raw transcript
# loaded 294 segments from model_data\gzHLv6rLSpQ.json
# processed transcript for gzHLv6rLSpQ of 12

# %% [markdown]
# Comment and Transcript extraction for tesla related videos:

# %%
tesla1="iueGI4CzP-0"
tesla2="52O3cYsyZMo"
tesla3="XTeWKmlNmN8"
tesla4="KAJFALcJjac"

# %%
tesla_1_df = extract_video_comments_full(tesla1,youtube_api,nlp, embedding, limit = 10000)
tesla_2_df = extract_video_comments_full(tesla2,youtube_api,nlp, embedding, limit = 10000)
tesla_3_df = extract_video_comments_full(tesla3,youtube_api,nlp, embedding, limit = 10000)
tesla_4_df = extract_video_comments_full(tesla4,youtube_api,nlp, embedding, limit = 10000)
# Out:
# iueGI4CzP-0_raw
# raw file dont exist, extracting comments
# Video iueGI4CzP-0: collected 150 rows so far
# Video iueGI4CzP-0: collected 284 rows so far
# Video iueGI4CzP-0: collected 411 rows so far
# Video iueGI4CzP-0: collected 517 rows so far
# Video iueGI4CzP-0: collected 638 rows so far
# Video iueGI4CzP-0: collected 744 rows so far
# Video iueGI4CzP-0: collected 856 rows so far
# Video iueGI4CzP-0: collected 991 rows so far
# Video iueGI4CzP-0: collected 1116 rows so far
# Video iueGI4CzP-0: collected 1230 rows so far
# Video iueGI4CzP-0: collected 1377 rows so far
# Video iueGI4CzP-0: collected 1510 rows so far
# Video iueGI4CzP-0: collected 1650 rows so far
# Video iueGI4CzP-0: collected 1777 rows so far
# Video iueGI4CzP-0: collected 1899 rows so far
# Video iueGI4CzP-0: collected 2026 rows so far
# Video iueGI4CzP-0: collected 2160 rows so far
# Video iueGI4CzP-0: collected 2333 rows so far
# Video iueGI4CzP-0: collected 2447 rows so far
# Video iueGI4CzP-0: collected 2560 rows so far
# Video iueGI4CzP-0: collected 2684 rows so far
# Video iueGI4CzP-0: collected 2811 rows so far
# Video iueGI4CzP-0: collected 2914 rows so far
# Video iueGI4CzP-0: collected 3021 rows so far
# Video iueGI4CzP-0: collected 3136 rows so far
# Video iueGI4CzP-0: collected 3246 rows so far
# Video iueGI4CzP-0: collected 3364 rows so far
# Video iueGI4CzP-0: collected 3480 rows so far
# Video iueGI4CzP-0: collected 3582 rows so far
# Video iueGI4CzP-0: collected 3740 rows so far
# Video iueGI4CzP-0: collected 3872 rows so far
# Video iueGI4CzP-0: collected 3996 rows so far
# Video iueGI4CzP-0: collected 4106 rows so far
# Video iueGI4CzP-0: collected 4335 rows so far
# Video iueGI4CzP-0: collected 4632 rows so far
# Video iueGI4CzP-0: collected 5078 rows so far
# extracted 5078 comments
# save iueGI4CzP-0_raw.csv of 5078 cols  to model_data\iueGI4CzP-0_raw.csv.csv
# Final number of comments after cleaning: 4758
# Comments removed: 320
# TF-IDF matrix shape: (4758, 4203)
# processed 4758 comments
# 52O3cYsyZMo_raw
# raw file dont exist, extracting comments
# Video 52O3cYsyZMo: collected 121 rows so far
# Video 52O3cYsyZMo: collected 253 rows so far
# Video 52O3cYsyZMo: collected 361 rows so far
# Video 52O3cYsyZMo: collected 471 rows so far
# Video 52O3cYsyZMo: collected 614 rows so far
# Video 52O3cYsyZMo: collected 742 rows so far
# Video 52O3cYsyZMo: collected 881 rows so far
# Video 52O3cYsyZMo: collected 997 rows so far
# Video 52O3cYsyZMo: collected 1116 rows so far
# Video 52O3cYsyZMo: collected 1230 rows so far
# Video 52O3cYsyZMo: collected 1352 rows so far
# Video 52O3cYsyZMo: collected 1512 rows so far
# Video 52O3cYsyZMo: collected 1634 rows so far
# Video 52O3cYsyZMo: collected 1744 rows so far
# Video 52O3cYsyZMo: collected 1868 rows so far
# Video 52O3cYsyZMo: collected 2025 rows so far
# Video 52O3cYsyZMo: collected 2396 rows so far
# Video 52O3cYsyZMo: collected 2772 rows so far
# Video 52O3cYsyZMo: collected 3149 rows so far
# extracted 3149 comments
# save 52O3cYsyZMo_raw.csv of 3149 cols  to model_data\52O3cYsyZMo_raw.csv.csv
# Final number of comments after cleaning: 2907
# Comments removed: 242
# TF-IDF matrix shape: (2907, 2452)
# processed 2907 comments
# XTeWKmlNmN8_raw
# raw file dont exist, extracting comments
# Video XTeWKmlNmN8: collected 181 rows so far
# Video XTeWKmlNmN8: collected 358 rows so far
# extracted 346 comments
# save XTeWKmlNmN8_raw.csv of 346 cols  to model_data\XTeWKmlNmN8_raw.csv.csv
# Final number of comments after cleaning: 304
# Comments removed: 42
# TF-IDF matrix shape: (304, 345)
# processed 304 comments
# KAJFALcJjac_raw
# raw file dont exist, extracting comments
# Video KAJFALcJjac: collected 133 rows so far
# Video KAJFALcJjac: collected 243 rows so far
# Video KAJFALcJjac: collected 376 rows so far
# Video KAJFALcJjac: collected 487 rows so far
# Video KAJFALcJjac: collected 602 rows so far
# Video KAJFALcJjac: collected 737 rows so far
# Video KAJFALcJjac: collected 958 rows so far
# extracted 924 comments
# save KAJFALcJjac_raw.csv of 924 cols  to model_data\KAJFALcJjac_raw.csv.csv
# Final number of comments after cleaning: 851
# Comments removed: 73
# TF-IDF matrix shape: (851, 942)
# processed 851 comments

# %%
tesla_tr_1_df = extract_video_transcript_full(tesla1,nlp,embedding,win=60)
tesla_tr_2_df = extract_video_transcript_full(tesla2,nlp,embedding,win=60)
tesla_tr_3_df = extract_video_transcript_full(tesla3,nlp,embedding,win=60)
tesla_tr_4_df = extract_video_transcript_full(tesla4,nlp,embedding,win=60)
# Out:
# saved 304 segments -> model_data\iueGI4CzP-0.json
# transcript does not exist, saving raw transcript
# loaded 304 segments from model_data\iueGI4CzP-0.json
# processed transcript for iueGI4CzP-0 of 12
# saved 348 segments -> model_data\52O3cYsyZMo.json
# transcript does not exist, saving raw transcript
# loaded 348 segments from model_data\52O3cYsyZMo.json
# processed transcript for 52O3cYsyZMo of 13
# saved 262 segments -> model_data\XTeWKmlNmN8.json
# transcript does not exist, saving raw transcript
# loaded 262 segments from model_data\XTeWKmlNmN8.json
# processed transcript for XTeWKmlNmN8 of 11
# saved 1262 segments -> model_data\KAJFALcJjac.json
# transcript does not exist, saving raw transcript
# loaded 1262 segments from model_data\KAJFALcJjac.json
# processed transcript for KAJFALcJjac of 45

# %% [markdown]
# transcript and comments for tesla vs byd videos

# %%
tvsb1='tezLYZHWkK4'
tvsb2='bEH5gDiESRg'
tvsb3='1umWTYuFVkY'

# %%
tvsb_1_df = extract_video_comments_full(tvsb1,youtube_api,nlp, embedding, limit = 10000)
tvsb_2_df = extract_video_comments_full(tvsb2,youtube_api,nlp, embedding, limit = 10000)
tvsb_3_df = extract_video_comments_full(tvsb3,youtube_api,nlp, embedding, limit = 10000)
tvsb_tr_1_df = extract_video_transcript_full(tvsb1,nlp,embedding,win=60)
tvsb_tr_2_df = extract_video_transcript_full(tvsb2,nlp,embedding,win=60)
tvsb_tr_3_df = extract_video_transcript_full(tvsb3,nlp,embedding,win=60)
# Out:
# raw file dont exist, extracting comments
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[68], line 2
#       1 # tvsb_1_df = extract_video_comments_full(tvsb1,youtube_api,nlp, embedding, limit = 10000)
# ----> 2 tvsb_2_df = extract_video_comments_full(tvsb2,youtube_api,nlp, embedding, limit = 10000)
#       3 tvsb_3_df = extract_video_comments_full(tvsb3,youtube_api,nlp, embedding, limit = 10000)
#       4 tvsb_tr_1_df = extract_video_transcript_full(tvsb1,nlp,embedding,win=60)
#       5 tvsb_tr_2_df = extract_video_transcript_full(tvsb2,nlp,embedding,win=60)
#
# File c:\Users\Abdallah\Desktop\uni\370 project\LLS-nlp-project\modules\pipelines.py:8, in extract_video_comments_full(video_id, youtube_api, nlp, embedding, limit)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\Abdallah\Desktop\uni\370 project\LLS-nlp-project\modules\comment_extraction.py:112, in extract_comments(youtube_api, video_id, limit)
#     107 def extract_comments(youtube_api, video_id,limit=100):
#     109   comments = []
#     111   comments.extend(
# --> 112       parse_top_comments(video_id, youtube_api,limit)
#     113   )
#     115   df = pd.DataFrame(comments)
#     116   df = df.drop_duplicates(subset=['source_id'])
#
# File c:\Users\Abdallah\Desktop\uni\370 project\LLS-nlp-project\modules\comment_extraction.py:64, in parse_top_comments(video_id, youtube_api, limit)
#      56 while True:
#      57     request = youtube_api.commentThreads().list(
#      58         part="snippet",
#      59         videoId=video_id,
#    (...)     62         textFormat="plainText",
#      63     )
# ---> 64     response = request.execute()
#      66     for item in response.get("items", []):
#      67         rows.append(top_level_format(item, video_id))
#
# File c:\Users\Abdallah\Desktop\uni\370 project\LLS-nlp-project\.venv\Lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File c:\Users\Abdallah\Desktop\uni\370 project\LLS-nlp-project\.venv\Lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     936     callback(resp)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=bEH5gDiESRg%26t%3D74s&maxResults=100&textFormat=plainText&key=AIzaSyBOqkhfjEr09SSRi4j4Yfu3HS9bm09MwnI&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">

# %%
# combines all transcript and comment dfs into one for metadata 

all_dfs = []
all_dfs.append(byd_tr_1_df)
all_dfs.append(byd_tr_2_df)
all_dfs.append(byd_tr_3_df)
all_dfs.append(byd_tr_4_df)
all_dfs.append(byd_tr_5_df)
all_dfs.append(byd_tr_6_df)
all_dfs.append(byd_tr_8_df)
all_dfs.append(byd_1_df)
all_dfs.append(byd_2_df)
all_dfs.append(byd_3_df)
all_dfs.append(byd_4_df)
all_dfs.append(byd_5_df)
all_dfs.append(byd_6_df)
all_dfs.append(byd_7_df)
all_dfs.append(byd_8_df)
all_dfs.append(tesla_tr_1_df)
all_dfs.append(tesla_tr_2_df)
all_dfs.append(tesla_tr_3_df)
all_dfs.append(tesla_tr_4_df)
all_dfs.append(tesla_1_df)
all_dfs.append(tesla_2_df)
all_dfs.append(tesla_3_df)
all_dfs.append(tesla_4_df)
all_dfs.append(tvsb_tr_1_df)
all_dfs.append(tvsb_tr_2_df)
all_dfs.append(tvsb_tr_3_df)
all_dfs.append(tvsb_1_df)
all_dfs.append(tvsb_2_df)
all_dfs.append(tvsb_3_df)
meta_df = pd.concat(all_dfs, ignore_index=True)
print(len(meta_df), "total rows")
print(meta_df["source_type"].value_counts())
print(meta_df["video_id"].value_counts())
# Out:
# 18527 total rows
# source_type
# comment       18325
# transcript      202
# Name: count, dtype: int64
# video_id
# iueGI4CzP-0    4770
# 52O3cYsyZMo    2920
# eNYndWedZsE    2000
# V0wtNI-rzSg    1890
# w_tCOgxXKwA    1591
# gzHLv6rLSpQ    1447
# Y8yTY_7w3KA     981
# KAJFALcJjac     896
# DHRxnTPrzOQ     864
# KLiiOeMU9JQ     778
# XTeWKmlNmN8     315
# JgySpSlQQyE      75
# Name: count, dtype: int64

# %%
texts, vectors, metadata = load_corpus_from_df(meta_df)
vs = build_faiss(texts, vectors, metadata, embedding)
save_df_csv(meta_df,f'meta_data',True)
# Out:
# loaded 18527 from                                                source_id source_type  \
# 0                                        w_tCOgxXKwA_t_0  transcript
# 1                                        w_tCOgxXKwA_t_1  transcript
# 2                                        w_tCOgxXKwA_t_2  transcript
# 3                                        w_tCOgxXKwA_t_3  transcript
# 4                                        w_tCOgxXKwA_t_4  transcript
# ...                                                  ...         ...
# 18522  UgxMaFscD6ukqrwF-jt4AaABAg.9k8_nX7rpK89k8g4nKD5D_     comment
# 18523  UgxMaFscD6ukqrwF-jt4AaABAg.9k8_nX7rpK89k8seOtj70Q     comment
# 18524  UgxMaFscD6ukqrwF-jt4AaABAg.9k8_nX7rpK89k8t28cy-2n     comment
# 18525  UgxMaFscD6ukqrwF-jt4AaABAg.9k8_nX7rpK89k8yVgzssca     comment
# 18526  UgxMaFscD6ukqrwF-jt4AaABAg.9k8_nX7rpK89k8ytSWz1mz     comment
#
#           video_id  chunk_index  start_time  \
# 0      w_tCOgxXKwA          0.0         0.1
# 1      w_tCOgxXKwA          1.0        58.7
# 2      w_tCOgxXKwA          2.0       117.1
# 3      w_tCOgxXKwA          3.0       175.5
# 4      w_tCOgxXKwA          4.0       235.4
# ...            ...          ...         ...
# 18522  KAJFALcJjac          NaN         NaN
# 18523  KAJFALcJjac          NaN         NaN
# 18524  KAJFALcJjac          NaN         NaN
# 18525  KAJFALcJjac          NaN         NaN
# 18526  KAJFALcJjac          NaN         NaN
#
#                                                     text  \
# 0      Ah, hello. You joined me on one of my favorite...
# 1      less filthy. The tires. So, what I've got here...
# 2      are very, very proud of its performance. That'...
# 3      there. It's where I keep my wellies and things...
# 4      update and now it looks so much better and has...
# ...                                                  ...
# 18522  @laloajuria4678 so I turned on the FSD preview...
# 18523  @roomotology8571 requires probably HW3. I thin...
# 18524  @z4zuse my car is a 2023 model. Just got it la...
# 18525  @roomotology8571 I am not sure if traffic ligh...
# 18526  @z4zuse it’s a bit strange. When I turned on t...
#
#                                             noun_phrases         entities  \
# 0      [Ah, hello, favorite days, favorite videos, a ...           [BYDC]
# 1      [The tires, wheels, size, the chunkiness, the ...               []
# 2      [performance, the back, a few people, liter, s...          [Tesco]
# 3      [wellies, things, muddy stuff, a frunk, L, cab...            [BYD]
# 4      [funky things, this software, everything, this...  [Apple CarPlay]
# ...                                                  ...              ...
# 18522                                                NaN            [FSD]
# 18523                                                NaN               []
# 18524                                                NaN               []
# 18525                                                NaN            [FSD]
# 18526                                                NaN            [FSD]
#
#                                                embedding  \
# 0      [-0.05210951, -0.046529986, 0.06541352, 0.0212...
# 1      [-0.03926401, -0.038578294, 0.039796773, -0.04...
# 2      [-0.040038507, -0.05510597, 0.0004025237, 0.00...
# 3      [-0.09188037, -0.06642025, 0.05645618, 0.02525...
# 4      [-0.088939704, -0.020354435, 0.012713011, 0.02...
# ...                                                  ...
# 18522  [-0.1139018, 0.015151713, 0.09449046, 0.051012...
# 18523  [-0.1058822, 0.038840484, 0.03619437, 0.005070...
# 18524  [-0.11635534, -0.012819063, 0.0449028, 0.00393...
# 18525  [-0.09556143, 0.026422998, 0.07155856, 0.04976...
# 18526  [-0.10222166, 0.0014091895, 0.07441306, 0.0616...
#
#                         parent_id is_reply            author  like_count  \
# 0                             NaN      NaN               NaN         NaN
# 1                             NaN      NaN               NaN         NaN
# 2                             NaN      NaN               NaN         NaN
# 3                             NaN      NaN               NaN         NaN
# 4                             NaN      NaN               NaN         NaN
# ...                           ...      ...               ...         ...
# 18522  UgxMaFscD6ukqrwF-jt4AaABAg     True  @roomotology8571         0.0
# 18523  UgxMaFscD6ukqrwF-jt4AaABAg     True           @z4zuse         0.0
# 18524  UgxMaFscD6ukqrwF-jt4AaABAg     True  @roomotology8571         0.0
# 18525  UgxMaFscD6ukqrwF-jt4AaABAg     True           @z4zuse         0.0
# 18526  UgxMaFscD6ukqrwF-jt4AaABAg     True  @roomotology8571         1.0
#
#       public                                         clean_text  \
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2        NaN                                                NaN
# 3        NaN                                                NaN
# 4        NaN                                                NaN
# ...      ...                                                ...
# 18522   True  so I turned on the FSD preview which is suppos...
# 18523   True  requires probably HW3. I think that HW2.5 is n...
# 18524   True  my car is a 2023 model. Just got it last week....
# 18525   True  I am not sure if traffic lights visualization ...
# 18526   True  it’s a bit strange. When I turned on the FSD v...
#
#        sentiment_score sentiment  \
# 0                  NaN       NaN
# 1                  NaN       NaN
# 2                  NaN       NaN
# 3                  NaN       NaN
# 4                  NaN       NaN
# ...                ...       ...
# 18522           0.0000   Neutral
# 18523           0.0000   Neutral
# 18524           0.0000   Neutral
# 18525          -0.2411  Negative
# 18526           0.7899  Positive
#
#                                                 keywords
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 18522     [turned, traffic lights, lights, fsd, traffic]
# 18523                      [sufficient, probably, think]
# 18524    [model just, 2023 model, doing, week, just got]
# 18525  [sufficient, visualization, traffic lights, en...
# 18526  [make sure, working, noticed, traffic lights, ...
#
# [18527 rows x 18 columns]
# built + saved FAISS index (18527 vectors) -> faiss_store
# save meta_data of 18527 cols  to model_data\meta_data.csv

# %%
meta_df.head()
# Out:
#          source_id source_type     video_id  chunk_index  start_time  \
# 0  w_tCOgxXKwA_t_0  transcript  w_tCOgxXKwA          0.0         0.1
# 1  w_tCOgxXKwA_t_1  transcript  w_tCOgxXKwA          1.0        58.7
# 2  w_tCOgxXKwA_t_2  transcript  w_tCOgxXKwA          2.0       117.1
# 3  w_tCOgxXKwA_t_3  transcript  w_tCOgxXKwA          3.0       175.5
# 4  w_tCOgxXKwA_t_4  transcript  w_tCOgxXKwA          4.0       235.4
#
#                                                 text  \
# 0  Ah, hello. You joined me on one of my favorite...
# 1  less filthy. The tires. So, what I've got here...
# 2  are very, very proud of its performance. That'...
# 3  there. It's where I keep my wellies and things...
# 4  update and now it looks so much better and has...
#
#                                         noun_phrases         entities  \
# 0  [Ah, hello, favorite days, favorite videos, a ...           [BYDC]
# 1  [The tires, wheels, size, the chunkiness, the ...               []
# 2  [performance, the back, a few people, liter, s...          [Tesco]
# 3  [wellies, things, muddy stuff, a frunk, L, cab...            [BYD]
# 4  [funky things, this software, everything, this...  [Apple CarPlay]
#
#                                            embedding parent_id is_reply  \
# 0  [-0.05210951, -0.046529986, 0.06541352, 0.0212...       NaN      NaN
# 1  [-0.03926401, -0.038578294, 0.039796773, -0.04...       NaN      NaN
# 2  [-0.040038507, -0.05510597, 0.0004025237, 0.00...       NaN      NaN
# 3  [-0.09188037, -0.06642025, 0.05645618, 0.02525...       NaN      NaN
# 4  [-0.088939704, -0.020354435, 0.012713011, 0.02...       NaN      NaN
#
#   author  like_count public clean_text  sentiment_score sentiment keywords
# 0    NaN         NaN    NaN        NaN              NaN       NaN      NaN
# 1    NaN         NaN    NaN        NaN              NaN       NaN      NaN
# 2    NaN         NaN    NaN        NaN              NaN       NaN      NaN
# 3    NaN         NaN    NaN        NaN              NaN       NaN      NaN
# 4    NaN         NaN    NaN        NaN              NaN       NaN      NaN

# %%
# from modules.retrieval import semantic_search

# for q in ["is tesla better than byd?", "what is the battery capacity and range?"]:
#     print(f"\nQ: {q}")
#     for r in semantic_search(vs, q, k=5):
#         print(r["source_type"], "|", r["text"][:70])
# Out:
# Q: is tesla better than byd?
# comment | Just tried byd and tesla model y. Tesla is better.
# comment | Is this brand BYD better than Toyota? That’s the question
# comment | Do you prefer the Tesla?
# comment | Is byd chinese version of tesla ?
# comment | I would like to see the side by side comparison between BYD and Tesla.
#
# Q: what is the battery capacity and range?
# comment | What is the range on it
# comment | kWh battery size?
# comment | you have not mentioned the range , the most important info
# comment | Just watched an ev review and don't know the range of the car or an ac
# comment | how about the autonomy? how many km/miles with a full charge? how many

# %%
# print("--- transcripts only ---")
# for r in filtered_search(vs, "what is the battery capacity and range?",
#                          source_type="transcript", k=5):
#     print(r["source_type"], "|", r["text"][:70])

# print("\n--- comments only ---")
# for r in filtered_search(vs, "is tesla better than byd?",
#                          source_type="comment", k=5):
#     print(r["source_type"], "|", r["text"][:70])
# Out:
# --- transcripts only ---
# transcript | kilometers, including some accelerations, so that could even be a litt
# transcript | battery, 82.5 kilowatt hours net, and it's an LFP battery that is also
# transcript | I've just got the key to this the byd seal so for the time being all o
# transcript | have them, that's a pro in comparison to the Tesla Model 3. Then 15.6-
# transcript | Inside of the rear doors, also the nice microfiber insert, high-grade
#
# --- comments only ---
# comment | ngl I might prefer byd over tesla
# comment | Only a crazy person would pick a BYD instead of a Tesla. All other EV
# comment | What type of idiot would say it's better than the model 3
# comment | Better than Tesla
# comment | I test drove both this and the model 3 performance. The Tesla is by fa

# %%
agent.VECTORSTORE = vs
graph = build_graph()

with mlflow.start_run(run_name='rag_router_test'):
  for q in ['what is the battery capacity?', 'is tesla better than byd']:
    result = graph.invoke({'query': q})
    print(f'\nQ: {q}')
    print(f'category: {result["category"]}')
    print(f'answer: {result["answer"]}')
# Out:
# Q: what is the battery capacity?
# category: factual
# answer: The context provided does not contain any relevant information about the battery capacity.
#
# Q: is tesla better than byd
# category: opinion
# answer: **Summary of opinions:**
# The comments reflect a **strong majority preference for BYD over Tesla**, with several users explicitly stating "BYD > Tesla" or expressing a personal preference for BYD. This sentiment is tied to perceptions of BYD as a **more competitive or cost-effective alternative** to Tesla, possibly due to its affordability, domestic market dominance, or technological advancements in electric vehicles.
#
# However, there is **nuanced debate** about the **contextual comparison** between BYD and Tesla. Some users question whether BYD is merely the "Chinese version of Tesla," implying a view of BYD as a **market-specific counterpart** rather than a direct superior. This framing suggests skepticism about BYD’s global competitiveness or innovation compared to Tesla.
#
# A **minority of comments** shift the comparison to **Toyota**, asking if BYD is better than Toyota. This indicates that some viewers are evaluating BYD against traditional automotive giants rather than Tesla, highlighting **divergent benchmarks** for assessing "better" (e.g., reliability, legacy, or market presence).
#
# **Common themes:**
# - **Praise for BYD**: Seen as a better option in terms of value, technology, or market positioning.
# - **Disagreement on comparison**: Some argue BYD is not a direct equivalent to Tesla but rather a distinct player in the Chinese market.
# - **Alternative benchmarks**: A few comments suggest evaluating BYD against Toyota instead of Tesla, reflecting varied criteria for "better."
#
# Overall, the sentiment leans toward **BYD being preferred over Tesla**, but the discussion underscores **contextual differences** in how users frame the comparison.

# %%
HARD_QUERIES = [
    {"query": "is the 82.5 kWh battery good?",                      "expected": "opinion"},  # fact + judgment
    {"query": "how does the range compare to what people hoped?",  "expected": "opinion"},  # spec + sentiment
    {"query": "what's the most complained-about feature?",         "expected": "opinion"},  # factual framing, opinion content
    {"query": "do the specs justify the price?",                   "expected": "opinion"},  # specs + value judgment
]

# %%
acc = evaluate_routing(graph, test_queries=HARD_QUERIES,model_name="qwen3:8b")
# Out:
# routing accuracy (qwen3:8b): 0.50
# (2/4)
#   not good[opinion vs factual] is the 82.5 kWh battery good?
#   not good[opinion vs factual] how does the range compare to what people hoped?
#   good[opinion vs opinion] what's the most complained-about feature?
#   good[opinion vs opinion] do the specs justify the price?

# %%
comments = meta_df[meta_df["source_type"] == "comment"]
lda, vec, doc_topics = run_lda(comments, "clean_text", n_topics=10)
print_topics(lda, vec, n_words=10)

per_sent = topics_per_sentiment(comments, n_topics=5)
print(per_sent)
# Out:
# fit LDA: 10 topics over 9505 docs, 1000 vocab terms
# Topic  0: byd tesla battery better model cars batteries range ev charging
# Topic  1: screen car phone just auto wow use rotating feature apple
# Topic  2: chinese cars car ev people electric buy like ccp don
# Topic  3: seal like model looks tesla better byd interior car good
# Topic  4: car charging speed range wait old bad charge heat ev
# Topic  5: like don wheel power steering right wrong need lfp change
# Topic  6: know did just don lol yes people car long make
# Topic  7: car byd driving drive thanks years good build test uk
# Topic  8: car great review love nice really miles reviews good ve
# Topic  9: china chinese price market car cars 000 byd europe world
# fit LDA: 5 topics over 2383 docs, 1000 vocab terms
#
# --- topics for sentiment: Negative ---
# Topic  0: byd tesla battery ev batteries don price charging
# Topic  1: chinese china car cars byd ev people just
# Topic  2: car cars tesla byd model like looks just
# Topic  3: screen review car use just useless don auto
# Topic  4: car bad electric cars wrong like just vehicle
# fit LDA: 5 topics over 2414 docs, 1000 vocab terms
#
# --- topics for sentiment: Neutral ---
# Topic  0: does screen fisker byd ocean just long new
# Topic  1: byd car tesla battery seal model did buy
# Topic  2: car think driving chinese said just people proof
# Topic  3: car china really charging charge model need ccp
# Topic  4: chinese cars china byd ev tesla just don
# fit LDA: 5 topics over 4708 docs, 1000 vocab terms
#
# --- topics for sentiment: Positive ---
# Topic  0: chinese china cars car byd like don buy
# Topic  1: like car looks great just screen drive look
# Topic  2: tesla model better seal byd good like car
# Topic  3: years byd people just lol like cars don
# Topic  4: car byd battery review range great love ev
# {'Negative': [['byd', 'tesla', 'battery', 'ev', 'batteries', 'don', 'price', 'charging'], ['chinese', 'china', 'car', 'cars', 'byd', 'ev', 'people', 'just'], ['car', 'cars', 'tesla', 'byd', 'model', 'like', 'looks', 'just'], ['screen', 'review', 'car', 'use', 'just', 'useless', 'don', 'auto'], ['car', 'bad', 'electric', 'cars', 'wrong', 'like', 'just', 'vehicle']], 'Neutral': [['does', 'screen', 'fisker', 'byd', 'ocean', 'just', 'long', 'new'], ['byd', 'car', 'tesla', 'battery', 'seal', 'model', 'did', 'buy'], ['car', 'think', 'driving', 'chinese', 'said', 'just', 'people', 'proof'], ['car', 'china', 'really', 'charging', 'charge', 'model', 'need', 'ccp'], ['chinese', 'cars', 'china', 'byd', 'ev', 'tesla', 'just', 'don']], 'Positive': [['chinese', 'china', 'cars', 'car', 'byd', 'like', 'don', 'buy'], ['like', 'car', 'looks', 'great', 'just', 'screen', 'drive', 'look'], ['tesla', 'model', 'better', 'seal', 'byd', 'good', 'like', 'car'], ['years', 'byd', 'people', 'just', 'lol', 'like', 'cars', 'don'], ['car', 'byd', 'battery', 'review', 'range', 'great', 'love', 'ev']]}
