# %% [markdown]
# imports and api

# %%
from comment_extraction import api_setup, extract_comments
from comment_class import RawComment
from mongo_code import mongo_connect, get_collection, insert_comments, convert_df_to_list

# %% [markdown]
# general functions for setup

# %%
youtube_api = api_setup()
video = "Y8yTY_7w3KA"

df1 = extract_comments(youtube_api,video)

df1.head()
# Out:
# loaded youtube api
# Video Y8yTY_7w3KA: collected 129 rows so far
# Video Y8yTY_7w3KA: collected 256 rows so far
# Video Y8yTY_7w3KA: collected 502 rows so far
# Video Y8yTY_7w3KA: collected 823 rows so far
# Video Y8yTY_7w3KA: collected 1037 rows so far
#                                           comment_id     video_id  \
# 0                         UgzjI6TjvTQiaNdFJDh4AaABAg  Y8yTY_7w3KA
# 1  UgzjI6TjvTQiaNdFJDh4AaABAg.9voUleYQpWB9vp-UsnhkGH  Y8yTY_7w3KA
# 2  UgzjI6TjvTQiaNdFJDh4AaABAg.9voUleYQpWB9vpI9k1jApB  Y8yTY_7w3KA
# 3  UgzjI6TjvTQiaNdFJDh4AaABAg.9voUleYQpWB9vytQZ977iX  Y8yTY_7w3KA
# 4  UgzjI6TjvTQiaNdFJDh4AaABAg.9voUleYQpWB9wBY-12Xroy  Y8yTY_7w3KA
#
#                     parent_id  is_reply        author  \
# 0                         NaN     False  @autogefuehl
# 1  UgzjI6TjvTQiaNdFJDh4AaABAg      True      @Rokii92
# 2  UgzjI6TjvTQiaNdFJDh4AaABAg      True       @Elaba_
# 3  UgzjI6TjvTQiaNdFJDh4AaABAg      True  @whatnow9653
# 4  UgzjI6TjvTQiaNdFJDh4AaABAg      True     @rondhole
#
#                                                 text  like_count  public
# 0  Note that contrary to the first info and contr...          57    True
# 1                        you mean "horror sound"? :D           0    True
# 2                     Tammy AI is without a job now.           0    True
# 3  1:29    lolly pops,  cherry pies,  cream puffs...           0    True
# 4  What separate a good and bad BEV is the heat m...           0    True

# %%
client = mongo_connect()
comments_db = client["comments_db"]

raw_comments = get_collection(comments_db, "raw_comments")

raw_comments_list = convert_df_to_list(df1)

inserted_comments = insert_comments(raw_comments, raw_comments_list)
# Out:
# connected to mongodb at mongodb://localhost:27017/
# inserted 1031 new comment(s)
